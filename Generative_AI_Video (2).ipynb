# %% [markdown]
# # **Important Libraries**

# %%
import google.generativeai as genai
from IPython.display import Markdown
from IPython.display import Video, display
from google.colab import userdata
import httpx
import base64
from PIL import Image

# %% [markdown]
# # **API Configuration**

# %%
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# # **Sample Video**

# %%
video_path = "/content/my_video.mp4"
with open(video_path, "rb") as video_file:
    video_data = base64.b64encode(video_file.read()).decode("utf-8")
display(Video(video_path, embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # **Video Prompt**

# %%
prompt = "Describe this video."

# %% [markdown]
# # **Model Selection**

# %%
model = genai.GenerativeModel(model_name="gemini-1.5-pro")

# %% [markdown]
# # **Model Response**

# %%
response = model.generate_content([


      {"mime_type": "video/mp4", "data": video_data},

      prompt,
])

Markdown(">"+response.text)
# Out:
# >This video introduces Abdullah Shahid, who is making a test video to determine how well his AI model understands video inputs. He wants to evaluate the performance of his model based on the simple video he has created.
